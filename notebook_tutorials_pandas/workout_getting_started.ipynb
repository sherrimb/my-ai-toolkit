# %% [markdown]
# # 🏆 Pandas Practice Worksheet: Putting the Tutorials Into Action 🚀
#
# Welcome to your **hands-on** Pandas workout! This worksheet will guide you through **core Pandas skills**, all derived from the tutorials you’ve just studied.

# %% [markdown]
# ## 💡 Step 0: Choose & Download a Dataset
# Head over to the **[Google Dataset Search Engine](https://datasetsearch.research.google.com/)** and pick a dataset that intrigues you! Aim for a **CSV or Excel** file with **at least a few columns**—and ideally one or two interesting features to explore.
#
# > **Suggested Datasets (Just Ideas!)**
# > - **World Happiness Report**
# > - **Global Earthquakes** (USGS)
# > - **IMDb Movies / TV Shows**
# > - **Weather Data** (NOAA)
# > - **Spotify / Music Streaming** Statistics
# >
# > Feel free to pick **any** dataset that piques your curiosity—just make sure it’s not **Titanic** or **Air Quality** so you can practice on something fresh!

# %% [markdown]
# ## 📥 Step 1: Import Pandas & Load Your Data
# 1. Import **pandas** (as `pd`) and optionally **matplotlib** for plotting.
# 2. Load your dataset using either `pd.read_csv(...)` or `pd.read_excel(...)`.
# 3. Preview the **first few rows** with `.head()`, and **last few rows** with `.tail()`.
#
# <details>
# <summary>Example Code Snippet</summary>
#
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt  # optional, only if you plan to do plots
#
# # Replace the file name/path below with your actual data
# df = pd.read_csv("your_dataset.csv")
#
# df.head()
#
# ```

# %%
import pandas as pd
import matplotlib as plt

# %%
ave_prices = pd.read_csv("../data/Average-prices-2024-07.csv")

# %%
ave_prices.head()
# Out:
#          Date       Region_Name  Area_Code  Average_Price  Monthly_Change  \
# 0  1968-04-01  Northern Ireland  N92000001    3661.485500             0.0
# 1  1968-04-01           England  E92000001    3408.108064             0.0
# 2  1968-04-01             Wales  W92000004    2885.414162             0.0
# 3  1968-04-01          Scotland  S92000003    2844.980688             0.0
# 4  1968-04-01            London  E12000007    4418.489911             0.0
#
#    Annual_Change  Average_Price_SA
# 0            NaN               NaN
# 1            NaN               NaN
# 2            NaN               NaN
# 3            NaN               NaN
# 4            NaN               NaN

# %%
ave_prices.tail()
# Out:
#               Date        Region_Name  Area_Code  Average_Price  \
# 142195  2024-07-01         Caerphilly  W06000018       191369.0
# 142196  2024-07-01      Blaenau Gwent  W06000019       131157.0
# 142197  2024-07-01  England and Wales  K04000001       301172.0
# 142198  2024-07-01      Great Britain  K03000001       292495.0
# 142199  2024-07-01     United Kingdom  K02000001       289723.0
#
#         Monthly_Change  Annual_Change  Average_Price_SA
# 142195             0.3            4.0               NaN
# 142196            -2.5            3.1               NaN
# 142197             0.2            1.6          296273.0
# 142198             0.6            2.2          287077.0
# 142199             0.6            2.2          284433.0

# %%
ave_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142200 entries, 0 to 142199
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              142200 non-null  object
#  1   Region_Name       142200 non-null  object
#  2   Area_Code         142200 non-null  object
#  3   Average_Price     142200 non-null  float64
#  4   Monthly_Change    141776 non-null  float64
#  5   Annual_Change     137388 non-null  float64
#  6   Average_Price_SA  4989 non-null    float64
# dtypes: float64(4), object(3)
# memory usage: 7.6+ MB

# %%
ave_prices.describe()
# Out:
#        Average_Price  Monthly_Change  Annual_Change  Average_Price_SA
# count   1.422000e+05   141776.000000  137388.000000       4989.000000
# mean    1.785838e+05        0.544986       6.307396     167574.205414
# std     1.218362e+05        1.955980       8.745112      88186.645899
# min     2.712016e+03      -30.297781     -35.786566      40405.313840
# 25%     1.005275e+05       -0.446124       1.242361     116567.964000
# 50%     1.545933e+05        0.500000       5.361429     156422.914300
# 75%     2.252271e+05        1.478041      10.408504     209484.507200
# max     1.531416e+06       35.286646      98.437940     534253.000000

# %%
ave_prices.dtypes
# Out:
# Date                 object
# Region_Name          object
# Area_Code            object
# Average_Price       float64
# Monthly_Change      float64
# Annual_Change       float64
# Average_Price_SA    float64
# dtype: object

# %% [markdown]
# ## 🔍 Step 3: Selecting Data (Subsets of Rows & Columns)
#
# 1.  **Select a single column** (e.g., `df["ColumnName"]`).
# 2.  **Select multiple columns** at once (e.g., `df[["ColA", "ColB"]]`).
# 3.  Use **boolean indexing** to filter rows (e.g., `df[df["ColA"] > 100]`).
# 4.  Try combining conditions with `&` (AND) or `|` (OR).
#
# -   Use **`.loc[]`** or **`.iloc[]`** to grab a specific subset, e.g., rows 10–20 and columns 2–4.
# -   Find all rows that match a certain condition (e.g., a specific category or numeric threshold).

# %%
ave_prices["Region_Name"]
# Out:
# 0          Northern Ireland
# 1                   England
# 2                     Wales
# 3                  Scotland
# 4                    London
#                 ...
# 142195           Caerphilly
# 142196        Blaenau Gwent
# 142197    England and Wales
# 142198        Great Britain
# 142199       United Kingdom
# Name: Region_Name, Length: 142200, dtype: object

# %%
ave_prices[["Region_Name", "Average_Price"]]
# Out:
#               Region_Name  Average_Price
# 0        Northern Ireland    3661.485500
# 1                 England    3408.108064
# 2                   Wales    2885.414162
# 3                Scotland    2844.980688
# 4                  London    4418.489911
# ...                   ...            ...
# 142195         Caerphilly  191369.000000
# 142196      Blaenau Gwent  131157.000000
# 142197  England and Wales  301172.000000
# 142198      Great Britain  292495.000000
# 142199     United Kingdom  289723.000000
#
# [142200 rows x 2 columns]

# %%
ave_prices[ave_prices["Average_Price"]>200000]
# Out:
#               Date             Region_Name  Area_Code  Average_Price  \
# 6615    1995-10-01  Kensington and Chelsea  E09000020    200005.8308
# 7341    1995-12-01  Kensington and Chelsea  E09000020    200722.0684
# 8797    1996-04-01  Kensington and Chelsea  E09000020    201218.2139
# 9150    1996-05-01  Kensington and Chelsea  E09000020    202340.5680
# 9854    1996-07-01  Kensington and Chelsea  E09000020    207443.2875
# ...            ...                     ...        ...            ...
# 142192  2024-07-01       Vale of Glamorgan  W06000014    292562.0000
# 142193  2024-07-01                 Cardiff  W06000015    272349.0000
# 142197  2024-07-01       England and Wales  K04000001    301172.0000
# 142198  2024-07-01           Great Britain  K03000001    292495.0000
# 142199  2024-07-01          United Kingdom  K02000001    289723.0000
#
#         Monthly_Change  Annual_Change  Average_Price_SA
# 6615          1.501157            NaN               NaN
# 7341          0.524405            NaN               NaN
# 8797          1.894697       9.252678               NaN
# 9150          0.557780       5.675156               NaN
# 9854          4.063483       4.788751               NaN
# ...                ...            ...               ...
# 142192       -3.300000      -1.500000               NaN
# 142193        1.100000       3.600000               NaN
# 142197        0.200000       1.600000          296273.0
# 142198        0.600000       2.200000          287077.0
# 142199        0.600000       2.200000          284433.0
#
# [45645 rows x 7 columns]

# %%
ave_prices[(ave_prices["Average_Price"]<200000) & (ave_prices["Region_Name"] == "Kensington and Chelsea")]
# Out:
#             Date             Region_Name  Area_Code  Average_Price  \
# 3370  1995-01-01  Kensington and Chelsea  E09000020    182694.8326
# 3730  1995-02-01  Kensington and Chelsea  E09000020    182345.2463
# 4101  1995-03-01  Kensington and Chelsea  E09000020    182878.8231
# 4449  1995-04-01  Kensington and Chelsea  E09000020    184176.9168
# 4803  1995-05-01  Kensington and Chelsea  E09000020    191474.1141
# 5167  1995-06-01  Kensington and Chelsea  E09000020    197265.7602
# 5520  1995-07-01  Kensington and Chelsea  E09000020    197963.3169
# 5906  1995-08-01  Kensington and Chelsea  E09000020    198037.4218
# 6258  1995-09-01  Kensington and Chelsea  E09000020    197047.8333
# 6991  1995-11-01  Kensington and Chelsea  E09000020    199674.9633
# 7699  1996-01-01  Kensington and Chelsea  E09000020    198311.8840
# 8061  1996-02-01  Kensington and Chelsea  E09000020    195949.6001
# 8412  1996-03-01  Kensington and Chelsea  E09000020    197476.6295
# 9505  1996-06-01  Kensington and Chelsea  E09000020    199343.0172
#
#       Monthly_Change  Annual_Change  Average_Price_SA
# 3370             NaN            NaN               NaN
# 3730       -0.191350            NaN               NaN
# 4101        0.292619            NaN               NaN
# 4449        0.709811            NaN               NaN
# 4803        3.962059            NaN               NaN
# 5167        3.024767            NaN               NaN
# 5520        0.353613            NaN               NaN
# 5906        0.037434            NaN               NaN
# 6258       -0.499698            NaN               NaN
# 6991       -0.165429            NaN               NaN
# 7699       -1.200757       8.548163               NaN
# 8061       -1.191196       7.460767               NaN
# 8412        0.779297       7.982229               NaN
# 9505       -1.481438       1.053025               NaN

# %%
ave_prices.iloc[10:21]
# Out:
#           Date               Region_Name  Area_Code  Average_Price  \
# 10  1968-05-01                   England  E92000001    3408.108064
# 11  1968-05-01          Northern Ireland  N92000001    3661.485500
# 12  1968-05-01                     Wales  W92000004    2885.414162
# 13  1968-05-01                  Scotland  S92000003    2844.980688
# 14  1968-05-01  Yorkshire and The Humber  E12000003    2712.015577
# 15  1968-05-01      West Midlands Region  E12000005    3328.858802
# 16  1968-05-01                    London  E12000007    4418.489911
# 17  1968-05-01             East Midlands  E12000004    3025.670615
# 18  1968-05-01                South West  E12000009    3468.159279
# 19  1968-05-01            United Kingdom  K02000001    3594.602239
# 20  1968-06-01                  Scotland  S92000003    2844.980688
#
#     Monthly_Change  Annual_Change  Average_Price_SA
# 10             0.0            NaN               NaN
# 11             0.0            NaN               NaN
# 12             0.0            NaN               NaN
# 13             0.0            NaN               NaN
# 14             0.0            NaN               NaN
# 15             0.0            NaN               NaN
# 16             0.0            NaN               NaN
# 17             0.0            NaN               NaN
# 18             0.0            NaN               NaN
# 19             0.0            NaN               NaN
# 20             0.0            NaN               NaN

# %%
ave_prices.loc[:,"Date"]
# Out:
# 0         1968-04-01
# 1         1968-04-01
# 2         1968-04-01
# 3         1968-04-01
# 4         1968-04-01
#              ...
# 142195    2024-07-01
# 142196    2024-07-01
# 142197    2024-07-01
# 142198    2024-07-01
# 142199    2024-07-01
# Name: Date, Length: 142200, dtype: object

# %%
london = ave_prices.loc[ave_prices["Area_Code"].str.startswith("E09")]
london
# Out:
#              Date           Region_Name  Area_Code  Average_Price  \
# 3351   1995-01-01         Tower Hamlets  E09000030    59865.18995
# 3352   1995-01-01        Waltham Forest  E09000031    61319.44913
# 3353   1995-01-01  Kingston upon Thames  E09000021    80875.84843
# 3354   1995-01-01               Lambeth  E09000022    67770.98843
# 3355   1995-01-01              Lewisham  E09000023    60491.26109
# ...           ...                   ...        ...            ...
# 141907 2024-07-01                Bexley  E09000004   401026.00000
# 141908 2024-07-01                 Brent  E09000005   513133.00000
# 141909 2024-07-01               Bromley  E09000006   503529.00000
# 141910 2024-07-01                Camden  E09000007   858303.00000
# 141911 2024-07-01               Croydon  E09000008   396032.00000
#
#         Monthly_Change  Annual_Change  Average_Price_SA
# 3351               NaN            NaN               NaN
# 3352               NaN            NaN               NaN
# 3353               NaN            NaN               NaN
# 3354               NaN            NaN               NaN
# 3355               NaN            NaN               NaN
# ...                ...            ...               ...
# 141907            -1.4            1.2               NaN
# 141908            -3.6           -0.1               NaN
# 141909             1.4            1.3               NaN
# 141910             2.6            2.8               NaN
# 141911             0.4           -0.6               NaN
#
# [11715 rows x 7 columns]

# %%
high_prices = ave_prices.loc[ave_prices["Average_Price"]>100000]
high_prices.head()
# Out:
#             Date             Region_Name  Area_Code  Average_Price  \
# 3359  1995-01-01                  Camden  E09000007    120932.8881
# 3362  1995-01-01  Hammersmith and Fulham  E09000013    124902.8602
# 3364  1995-01-01     City of Westminster  E09000033    133025.2772
# 3370  1995-01-01  Kensington and Chelsea  E09000020    182694.8326
# 3381  1995-01-01    Richmond upon Thames  E09000027    109326.1245
#
#       Monthly_Change  Annual_Change  Average_Price_SA
# 3359             NaN            NaN               NaN
# 3362             NaN            NaN               NaN
# 3364             NaN            NaN               NaN
# 3370             NaN            NaN               NaN
# 3381             NaN            NaN               NaN

# %%
negative_change = ave_prices.loc[ave_prices['Annual_Change'] < 0]
negative_change
# Out:
#               Date         Region_Name  Area_Code  Average_Price  \
# 157     1969-07-01       East Midlands  E12000004    3159.821224
# 165     1969-08-01       East Midlands  E12000004    3159.821224
# 177     1969-09-01       East Midlands  E12000004    3159.821224
# 182     1969-10-01    Northern Ireland  N92000001    3703.571540
# 193     1969-11-01    Northern Ireland  N92000001    3703.571540
# ...            ...                 ...        ...            ...
# 142156  2024-07-01       Isle of Wight  E06000046  274859.000000
# 142163  2024-07-01             Rutland  E06000017  377274.000000
# 142173  2024-07-01              Torbay  E06000027  250339.000000
# 142176  2024-07-01  North Lincolnshire  E06000013  180655.000000
# 142192  2024-07-01   Vale of Glamorgan  W06000014  292562.000000
#
#         Monthly_Change  Annual_Change  Average_Price_SA
# 157           1.587302      -0.461584               NaN
# 165           1.587302      -0.461584               NaN
# 177           1.587302      -0.461584               NaN
# 182           2.325581      -5.376344               NaN
# 193           2.325581      -5.376344               NaN
# ...                ...            ...               ...
# 142156       -0.300000      -2.100000               NaN
# 142163        1.000000      -8.700000               NaN
# 142173       -0.500000      -2.300000               NaN
# 142176       -3.500000      -0.200000               NaN
# 142192       -3.300000      -1.500000               NaN
#
# [25800 rows x 7 columns]

# %%
ave_prices.iloc[10:21,2:5]
# Out:
#     Area_Code  Average_Price  Monthly_Change
# 10  E92000001    3408.108064             0.0
# 11  N92000001    3661.485500             0.0
# 12  W92000004    2885.414162             0.0
# 13  S92000003    2844.980688             0.0
# 14  E12000003    2712.015577             0.0
# 15  E12000005    3328.858802             0.0
# 16  E12000007    4418.489911             0.0
# 17  E12000004    3025.670615             0.0
# 18  E12000009    3468.159279             0.0
# 19  K02000001    3594.602239             0.0
# 20  S92000003    2844.980688             0.0

# %%
england.plot()
# Out:
# <Axes: >

# %%
england.plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# First, i need to change Date column to datetime format
ave_prices["Date"] = pd.to_datetime(ave_prices["Date"])

# %%
_2010_2024 = ave_prices.loc[(ave_prices["Date"].dt.year>=2010)&(ave_prices["Date"].dt.year<=2024)]
_2010_2024
# Out:
#              Date        Region_Name  Area_Code  Average_Price  \
# 71325  2010-01-01              Wales  W92000004    127732.6597
# 71326  2010-01-01   Northern Ireland  N92000001    135701.4807
# 71327  2010-01-01           Scotland  S92000003    128972.9001
# 71328  2010-01-01            England  E92000001    174457.5959
# 71329  2010-01-01       Inner London  E13000001    324531.4238
# ...           ...                ...        ...            ...
# 142195 2024-07-01         Caerphilly  W06000018    191369.0000
# 142196 2024-07-01      Blaenau Gwent  W06000019    131157.0000
# 142197 2024-07-01  England and Wales  K04000001    301172.0000
# 142198 2024-07-01      Great Britain  K03000001    292495.0000
# 142199 2024-07-01     United Kingdom  K02000001    289723.0000
#
#         Monthly_Change  Annual_Change  Average_Price_SA
# 71325        -3.944716       2.168675       128754.1867
# 71326        -4.431390      -3.201716               NaN
# 71327        -3.054670       3.605994       129959.1321
# 71328         0.184625       7.244661       174872.8599
# 71329         1.851917       8.967159               NaN
# ...                ...            ...               ...
# 142195        0.300000       4.000000               NaN
# 142196       -2.500000       3.100000               NaN
# 142197        0.200000       1.600000       296273.0000
# 142198        0.600000       2.200000       287077.0000
# 142199        0.600000       2.200000       284433.0000
#
# [70875 rows x 7 columns]

# %%
london = _2010_2024.loc[_2010_2024["Area_Code"].str.startswith("E09")]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size
plt.figure(figsize=(12,6))

# Get unique region names
regions = london["Region_Name"].unique()

# Use Seaborn color palette for different regions
colors = sns.color_palette("tab10", len(regions))

# Plot each region separately with a unique color
for i, region in enumerate(regions):
    subset = london[london["Region_Name"] == region]
    plt.scatter(subset["Date"], subset["Average_Price"], color=colors[i], label=region, alpha=0.6)

# Labels and title
plt.xlabel("Year")
plt.ylabel("Average Price (£)")
plt.title("Average House Prices in Inner London Regions (2010-2024)")
plt.xticks(rotation=45)
plt.legend(title="Region", bbox_to_anchor=(1.05, 1), loc='upper left')  # Move legend outside plot
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(12,6))

# Plot as a line graph
for i, region in enumerate(regions):
    subset = london[london["Region_Name"] == region]
    plt.plot(subset["Date"], subset["Average_Price"], marker='o', color=colors[i], label=region, alpha=0.6)

plt.xlabel("Year")
plt.ylabel("Average Price (£)")
plt.title("Average House Prices in Inner London Regions (2010-2024)")
plt.xticks(rotation=45)
plt.legend(title="Region", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)

plt.show()

# %%
# Aggregate data to yearly averages
london["Year"] = london["Date"].dt.year  # Extract year
yearly_avg = london.groupby(["Year", "Region_Name"])["Average_Price"].mean().reset_index()

# Plot
plt.figure(figsize=(12,6))

for i, region in enumerate(regions):
    subset = yearly_avg[yearly_avg["Region_Name"] == region]
    plt.plot(subset["Year"], subset["Average_Price"], marker='o', color=colors[i], label=region, alpha=0.6)

plt.xlabel("Year")
plt.ylabel("Average Price (£)")
plt.title("Yearly Average House Prices in Inner London (2010-2024)")
plt.xticks(rotation=45)
plt.legend(title="Region", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)

plt.show()
# Out:
# /tmp/ipykernel_10377/613539015.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   london["Year"] = london["Date"].dt.year  # Extract year
